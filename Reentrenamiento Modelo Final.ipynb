# %%
import pymongo
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from pickle import dump
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
from keras.losses import Huber, huber
from tensorflow.keras.utils import set_random_seed

# %%
set_random_seed(812)

# %% [markdown]
# Conexión a la base de datos y tratamiento de ellos

# %%
client = pymongo.MongoClient("mongodb+srv://braisbugallo:1234567890@cluster0.csyeqkh.mongodb.net/")

# %%
df = pd.DataFrame(list(client.weather.data.find() ))

# %%
client.close()

# %%
df['weather'] = df['weather'].apply(lambda x: x[0] if len(x) > 0 else None)
df['clouds'] = df['clouds'].apply(lambda x: x["all"])
df['rain'] = df['rain'].apply(lambda x: x.get("1h") if isinstance(x, dict) else None)
df['snow'] = df['snow'].apply(lambda x: x.get("1h") if isinstance(x, dict) else None)
df = df\
        .join(pd.json_normalize(df['main']))\
        .drop(columns=['main'])\
        .join(pd.json_normalize(df['wind']))\
        .drop(columns=['wind'])\
        .join(pd.json_normalize(df['weather']))\
        .drop(columns=['weather'])\
        .rename(columns = {"speed": "wind_speed", 
                           "deg": "wind_deg",
                           "gust": "wind_gust",
                           "main": "weather", 
                           "description": 
                           "weather_description"})\
                        [['datetime', 'city', 'weather','clouds', 'temp',
                          'feels_like', 'pressure', 'humidity', 'temp_min', 'temp_max',
                          'wind_speed', 'wind_deg', 'wind_gust', 'rain', 'snow']]\
        .drop_duplicates()\
        .sort_values(by=['datetime', 'city'])\
        .reset_index(drop=True)

# %% [markdown]
# Codificamos las ciudades con sus coordenadas

# %%
coordinates = {
    'A Coruna': [43.3623, -8.4115],
    'Albacete': [38.9944, -1.8585],
    'Almeria': [36.8381, -2.4597],
    'Avila de los Caballeros': [40.6566, -4.7000],
    'Badajoz': [38.8794, -6.9707],
    'Barcelona': [41.3851, 2.1734],
    'Burgos': [42.3436, -3.6969],
    'Caceres': [39.4745, -6.3711],
    'Cadiz': [36.5298, -6.2920],
    'Castello de la Plana': [39.9864, -0.0513],
    'Ciudad Real': [38.9863, -3.9293],
    'Cordoba': [37.8882, -4.7794],
    'Cuenca': [40.0704, -2.1374],
    'Girona': [41.9793, 2.8197],
    'Granada': [37.1773, -3.5986],
    'Guadalajara': [40.6327, -3.1627],
    'Huelva': [37.2614, -6.9447],
    'Huesca': [42.1361, -0.4087],
    'Jaen': [37.7796, -3.7841],
    'Las Palmas de Gran Canaria': [28.1248, -15.4300],
    'Leon': [42.5987, -5.5671],
    'Lleida': [41.6176, 0.6200],
    'Logrono': [42.4668, -2.4499],
    'Lugo': [43.0129, -7.5550],
    'Madrid': [40.4168, -3.7038],
    'Malaga': [36.7213, -4.4215],
    'Murcia': [37.9922, -1.1307],
    'Ourense': [42.3409, -7.8641],
    'Oviedo': [43.3614, -5.8593],
    'Palencia': [42.0095, -4.5278],
    'Pamplona': [42.8125, -1.6458],
    'Pontevedra': [42.4317, -8.6445],
    'Santander': [43.4623, -3.8099],
    'Segovia': [40.9429, -4.1088],
    'Sevilla': [37.3886, -5.9823],
    'Soria': [41.7636, -2.4649],
    'Tarragona': [41.1189, 1.2445],
    'Teruel': [40.3440, -1.1060],
    'Toledo': [39.8628, -4.0273],
    'Valencia': [39.4699, -0.3763],
    'Valladolid': [41.6520, -4.7245],
    'Vitoria-Gasteiz': [42.8592, -2.6818],
    'Zamora': [41.5034, -5.7460],
    'Zaragoza': [41.6488, -0.8891]
}
df['latitude'] = df['city'].apply(lambda x: coordinates[x][0])
df['longitude'] = df['city'].apply(lambda x: coordinates[x][1])

# %% [markdown]
# Codificar weather, dummificando

# %%
df = df.join( pd.get_dummies(df["weather"],prefix='w', prefix_sep='-', dtype = float))\
        .fillna(0)

# %% [markdown]
# convertimos datetime a un formato de fecha y extraemos las características año, mes, día, día de semana y hora

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

df['año'] = df['datetime'].dt.year
df['mes'] = df['datetime'].dt.month
df['día'] = df['datetime'].dt.day
df['día_semana'] = df['datetime'].dt.dayofweek
df['hora'] = df['datetime'].dt.hour

# %% [markdown]
# Nos quedamos con las columnas que utilizaremos

# %%
df = df[['latitude','longitude', 'hora', 'año', 'mes', 'día', 'día_semana',
         'w-Clear', 'w-Clouds', 'w-Drizzle','w-Dust', 'w-Fog', 'w-Haze', 
         'w-Mist', 'w-Rain', 'w-Snow', 'w-Squall', 'w-Thunderstorm', 
         'clouds', 'temp', 'pressure', 'humidity', 
         'temp_min', 'temp_max', 'wind_speed', 'wind_deg', 'wind_gust',
         'rain', 'snow', 'datetime']]

# %%
num_steps = 5

# %%
df_new = df[(df['datetime'] >= '2023-05-22') & (df['datetime'] < '2024-06-17')].reset_index(drop = True)
for i in range(num_steps):
    start = len(df[df['datetime'] < '2023-05-22']) - (i+1)*24*44
    end = len(df[df['datetime'] < '2023-05-22']) - (i+1)*24*44 + len(df_new)
    df_new = pd.concat([df_new, df[start:end][['clouds','temp', 'pressure',
                                               'humidity', 'temp_min', 'temp_max','wind_speed',
                                               'wind_deg', 'wind_gust', 'rain', 'snow']]\
                                                .reset_index(drop = True)\
                                                .rename(columns=lambda x: x + f'_{i+1}')],axis = 1)

# %% [markdown]
# Numero de horas previas con las que alimentaremos el modelo para predecir la hora pedida.

# %% [markdown]
# Separar características y etiquetas

# %%
X = df_new[['latitude', 'longitude', 'año', 'mes', 'día', 'día_semana', 'hora'] +
           [f'clouds_{i+1}' for i in range(num_steps)] +
           [f'temp_{i+1}' for i in range(num_steps)] +
           [f'pressure_{i+1}' for i in range(num_steps)] +
           [f'humidity_{i+1}' for i in range(num_steps)] +
           [f'temp_min_{i+1}' for i in range(num_steps)] +
           [f'temp_max_{i+1}' for i in range(num_steps)] +
           [f'wind_speed_{i+1}' for i in range(num_steps)] +
           [f'wind_deg_{i+1}' for i in range(num_steps)] +
           [f'wind_gust_{i+1}' for i in range(num_steps)] +
           [f'rain_{i+1}' for i in range(num_steps)] +
           [f'snow_{i+1}' for i in range(num_steps)]]
y = df_new[['clouds', 'temp', 'pressure', 'humidity', 'temp_min', 
            'temp_max', 'wind_speed', 'wind_deg', 'wind_gust', 'rain', 'snow']]

# %% [markdown]
# Escalar los datos

# %%
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y)
dump(scaler_X, open(f"scaler_X_1-more-week.pkl", 'wb'))
dump(scaler_y, open(f"scaler_y_1-more-week.pkl", 'wb'))

# %% [markdown]
# Transformamos los datos para tener en cada entrada del array los datos de una hora para todas las ciudades

# %%
y_reshaped = []
for i in range(len(y_scaled)//44):
    y_reshaped += [y_scaled[0+44*i:44+44*i]]
y_reshaped = np.array(y_reshaped)

# %%
X_reshaped = []
for i in range(len(X_scaled)//44):
    X_reshaped += [X_scaled[0+44*i:44+44*i]]
X_reshaped = np.array(X_reshaped)

# %%
X_reshaped.shape
# Out:
# (9408, 44, 62)

# %%
y_reshaped.shape
# Out:
# (9408, 44, 11)

# %% [markdown]
# Seleccionamos los datos para entrenar, 53 semanas, así tendremos un año entero de datos menos un día, para que las predicciones comiencen en un lunes.
# El conjunto de validacion contendra dos semanas de datos y el de test una semana.

# %%
split = 53*7*24
split_2 = split + 2*7*24

# %% [markdown]
# Separamos los datos en entrenamiento y prueba, X_test lo definiremos una vez tengamos el modelo, ya que utilizará valores predichos.

# %%
X_train = X_reshaped[0:split]
X_val = X_reshaped[split:split_2]
X_test  = X_reshaped[split_2:]
y_train = y_reshaped[0:split]
y_val = y_reshaped[split:split_2]
y_test  = y_reshaped[split_2:]

# %% [markdown]
# Modelo cnn-lstm

# %%
def build_cnn_lstm(input_shape, output_shape):
    model = Sequential()
    
    # Primera capa Conv1D
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Primera capa LSTM
    model.add(LSTM(128, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Segunda capa Conv1D
    model.add(Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Segunda capa LSTM
    model.add(LSTM(64, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Capas densas
    model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    
    model.add(Dense(output_shape, activation='linear'))
    
    return model

# %% [markdown]
# Construimos y compilamos el modelo

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
output_shape = y_train.shape[2]
model = build_cnn_lstm(input_shape, output_shape)
optimizer = Adam()
loss = Huber()
model.compile(optimizer=optimizer, loss=loss, metrics=['mae','mse'])
# Out:
# C:\Users\Brais\.conda\envs\TFM\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 44, 128)             │          23,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 44, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 44, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 44, 128)             │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 44, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 44, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 44, 64)              │          24,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 44, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 44, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 44, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 44, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 44, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 44, 32)              │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 44, 32)              │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 44, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 44, 32)              │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 44, 32)              │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 44, 11)              │             363 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 218,475 (853.42 KB)
#  Trainable params: 217,579 (849.92 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
history = model.fit(X_train, 
                    y_train, 
                    epochs=200,
                    batch_size=128, 
                    validation_data=(X_val, y_val),
                    callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)])
# Out:
# Epoch 1/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step - loss: 1.0329 - mae: 0.7292 - mse: 0.9815 - val_loss: 0.4359 - val_mae: 0.2566 - val_mse: 0.1116
# Epoch 2/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.4038 - mae: 0.3090 - mse: 0.1840 - val_loss: 0.1955 - val_mae: 0.1759 - val_mse: 0.0513
# Epoch 3/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.1711 - mae: 0.1758 - mse: 0.0630 - val_loss: 0.0893 - val_mae: 0.1258 - val_mse: 0.0357
# Epoch 4/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0773 - mae: 0.1323 - mse: 0.0384 - val_loss: 0.0471 - val_mae: 0.1259 - val_mse: 0.0373
# Epoch 5/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0392 - mae: 0.1185 - mse: 0.0325 - val_loss: 0.0284 - val_mae: 0.1206 - val_mse: 0.0349
# Epoch 6/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0239 - mae: 0.1113 - mse: 0.0301 - val_loss: 0.0211 - val_mae: 0.1182 - val_mse: 0.0337
# Epoch 7/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0188 - mae: 0.1105 - mse: 0.0300 - val_loss: 0.0201 - val_mae: 0.1237 - val_mse: 0.0361
# Epoch 8/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0156 - mae: 0.1036 - mse: 0.0278 - val_loss: 0.0175 - val_mae: 0.1137 - val_mse: 0.0331
# Epoch 9/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0144 - mae: 0.1012 - mse: 0.0271 - val_loss: 0.0172 - val_mae: 0.1163 - val_mse: 0.0332
# Epoch 10/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0148 - mae: 0.1053 - mse: 0.0281 - val_loss: 0.0177 - val_mae: 0.1136 - val_mse: 0.0345
# Epoch 11/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0133 - mae: 0.0975 - mse: 0.0256 - val_loss: 0.0170 - val_mae: 0.1087 - val_mse: 0.0334
# Epoch 12/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0128 - mae: 0.0953 - mse: 0.0249 - val_loss: 0.0180 - val_mae: 0.1194 - val_mse: 0.0353
# Epoch 13/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0128 - mae: 0.0958 - mse: 0.0248 - val_loss: 0.0146 - val_mae: 0.1064 - val_mse: 0.0285
# Epoch 14/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0125 - mae: 0.0937 - mse: 0.0242 - val_loss: 0.0127 - val_mae: 0.0950 - val_mse: 0.0249
# Epoch 15/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0123 - mae: 0.0932 - mse: 0.0241 - val_loss: 0.0148 - val_mae: 0.1063 - val_mse: 0.0291
# Epoch 16/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0121 - mae: 0.0920 - mse: 0.0237 - val_loss: 0.0252 - val_mae: 0.1409 - val_mse: 0.0499
# Epoch 17/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0119 - mae: 0.0910 - mse: 0.0233 - val_loss: 0.0163 - val_mae: 0.1146 - val_mse: 0.0322
# Epoch 18/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0119 - mae: 0.0913 - mse: 0.0233 - val_loss: 0.0479 - val_mae: 0.1968 - val_mse: 0.0951
# Epoch 19/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0119 - mae: 0.0915 - mse: 0.0233 - val_loss: 0.0170 - val_mae: 0.1160 - val_mse: 0.0334
# Epoch 20/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0119 - mae: 0.0909 - mse: 0.0232 - val_loss: 0.0115 - val_mae: 0.0840 - val_mse: 0.0224
# Epoch 21/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0116 - mae: 0.0892 - mse: 0.0227 - val_loss: 0.0131 - val_mae: 0.0965 - val_mse: 0.0256
# Epoch 22/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0116 - mae: 0.0889 - mse: 0.0225 - val_loss: 0.0145 - val_mae: 0.0993 - val_mse: 0.0285
# Epoch 23/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0115 - mae: 0.0885 - mse: 0.0224 - val_loss: 0.0131 - val_mae: 0.0921 - val_mse: 0.0257
# Epoch 24/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0113 - mae: 0.0876 - mse: 0.0221 - val_loss: 0.0131 - val_mae: 0.0955 - val_mse: 0.0255
# Epoch 25/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0113 - mae: 0.0873 - mse: 0.0220 - val_loss: 0.0120 - val_mae: 0.0885 - val_mse: 0.0235
# Epoch 26/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0111 - mae: 0.0868 - mse: 0.0218 - val_loss: 0.0134 - val_mae: 0.0965 - val_mse: 0.0263
# Epoch 27/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0111 - mae: 0.0864 - mse: 0.0217 - val_loss: 0.0155 - val_mae: 0.1018 - val_mse: 0.0305
# Epoch 28/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0110 - mae: 0.0861 - mse: 0.0216 - val_loss: 0.0133 - val_mae: 0.0953 - val_mse: 0.0261
# Epoch 29/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0109 - mae: 0.0855 - mse: 0.0214 - val_loss: 0.0108 - val_mae: 0.0813 - val_mse: 0.0212
# Epoch 30/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0109 - mae: 0.0850 - mse: 0.0213 - val_loss: 0.0112 - val_mae: 0.0827 - val_mse: 0.0219
# Epoch 31/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0108 - mae: 0.0849 - mse: 0.0212 - val_loss: 0.0127 - val_mae: 0.0898 - val_mse: 0.0251
# Epoch 32/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - loss: 0.0108 - mae: 0.0852 - mse: 0.0212 - val_loss: 0.0112 - val_mae: 0.0826 - val_mse: 0.0219
# Epoch 33/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0108 - mae: 0.0845 - mse: 0.0211 - val_loss: 0.0107 - val_mae: 0.0808 - val_mse: 0.0210
# Epoch 34/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - loss: 0.0107 - mae: 0.0840 - mse: 0.0209 - val_loss: 0.0110 - val_mae: 0.0826 - val_mse: 0.0214
# Epoch 35/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - loss: 0.0107 - mae: 0.0842 - mse: 0.0209 - val_loss: 0.0107 - val_mae: 0.0802 - val_mse: 0.0209
# Epoch 36/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.0107 - mae: 0.0843 - mse: 0.0209 - val_loss: 0.0107 - val_mae: 0.0789 - val_mse: 0.0208
# Epoch 37/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.0106 - mae: 0.0830 - mse: 0.0207 - val_loss: 0.0121 - val_mae: 0.0858 - val_mse: 0.0237
# Epoch 38/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - loss: 0.0106 - mae: 0.0832 - mse: 0.0207 - val_loss: 0.0126 - val_mae: 0.0870 - val_mse: 0.0248
# Epoch 39/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.0105 - mae: 0.0832 - mse: 0.0205 - val_loss: 0.0107 - val_mae: 0.0781 - val_mse: 0.0210
# Epoch 40/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.0104 - mae: 0.0822 - mse: 0.0203 - val_loss: 0.0104 - val_mae: 0.0765 - val_mse: 0.0205
# Epoch 41/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.0103 - mae: 0.0822 - mse: 0.0203 - val_loss: 0.0105 - val_mae: 0.0784 - val_mse: 0.0207
# Epoch 42/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - loss: 0.0103 - mae: 0.0820 - mse: 0.0202 - val_loss: 0.0106 - val_mae: 0.0796 - val_mse: 0.0208
# Epoch 43/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - loss: 0.0102 - mae: 0.0815 - mse: 0.0200 - val_loss: 0.0104 - val_mae: 0.0781 - val_mse: 0.0205
# Epoch 44/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0101 - mae: 0.0810 - mse: 0.0198 - val_loss: 0.0108 - val_mae: 0.0772 - val_mse: 0.0212
# Epoch 45/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 0.0101 - mae: 0.0810 - mse: 0.0198 - val_loss: 0.0108 - val_mae: 0.0784 - val_mse: 0.0213
# Epoch 46/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0100 - mae: 0.0806 - mse: 0.0196 - val_loss: 0.0115 - val_mae: 0.0825 - val_mse: 0.0227
# Epoch 47/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0100 - mae: 0.0808 - mse: 0.0197 - val_loss: 0.0104 - val_mae: 0.0784 - val_mse: 0.0205
# Epoch 48/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 0.0099 - mae: 0.0804 - mse: 0.0196 - val_loss: 0.0113 - val_mae: 0.0830 - val_mse: 0.0222
# Epoch 49/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0098 - mae: 0.0799 - mse: 0.0194 - val_loss: 0.0109 - val_mae: 0.0823 - val_mse: 0.0216
# Epoch 50/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0098 - mae: 0.0795 - mse: 0.0193 - val_loss: 0.0110 - val_mae: 0.0826 - val_mse: 0.0216
# Epoch 51/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0097 - mae: 0.0794 - mse: 0.0192 - val_loss: 0.0104 - val_mae: 0.0763 - val_mse: 0.0206
# Epoch 52/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0097 - mae: 0.0791 - mse: 0.0192 - val_loss: 0.0104 - val_mae: 0.0762 - val_mse: 0.0206
# Epoch 53/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0097 - mae: 0.0789 - mse: 0.0191 - val_loss: 0.0106 - val_mae: 0.0780 - val_mse: 0.0210
# Epoch 54/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0096 - mae: 0.0788 - mse: 0.0189 - val_loss: 0.0108 - val_mae: 0.0793 - val_mse: 0.0215
# Epoch 55/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0095 - mae: 0.0784 - mse: 0.0189 - val_loss: 0.0104 - val_mae: 0.0765 - val_mse: 0.0207
# Epoch 56/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0094 - mae: 0.0778 - mse: 0.0187 - val_loss: 0.0107 - val_mae: 0.0764 - val_mse: 0.0212
# Epoch 57/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0094 - mae: 0.0775 - mse: 0.0186 - val_loss: 0.0103 - val_mae: 0.0768 - val_mse: 0.0204
# Epoch 58/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - loss: 0.0093 - mae: 0.0773 - mse: 0.0185 - val_loss: 0.0105 - val_mae: 0.0767 - val_mse: 0.0208
# Epoch 59/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.0093 - mae: 0.0770 - mse: 0.0184 - val_loss: 0.0103 - val_mae: 0.0756 - val_mse: 0.0205
# Epoch 60/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0092 - mae: 0.0766 - mse: 0.0183 - val_loss: 0.0109 - val_mae: 0.0777 - val_mse: 0.0216
# Epoch 61/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 0.0092 - mae: 0.0764 - mse: 0.0182 - val_loss: 0.0106 - val_mae: 0.0771 - val_mse: 0.0210
# Epoch 62/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0092 - mae: 0.0761 - mse: 0.0182 - val_loss: 0.0107 - val_mae: 0.0776 - val_mse: 0.0212
# Epoch 63/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0091 - mae: 0.0760 - mse: 0.0181 - val_loss: 0.0103 - val_mae: 0.0762 - val_mse: 0.0204
# Epoch 64/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0091 - mae: 0.0757 - mse: 0.0180 - val_loss: 0.0102 - val_mae: 0.0755 - val_mse: 0.0202
# Epoch 65/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 0.0091 - mae: 0.0758 - mse: 0.0180 - val_loss: 0.0104 - val_mae: 0.0760 - val_mse: 0.0207
# Epoch 66/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0090 - mae: 0.0750 - mse: 0.0178 - val_loss: 0.0103 - val_mae: 0.0764 - val_mse: 0.0204
# Epoch 67/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0089 - mae: 0.0750 - mse: 0.0177 - val_loss: 0.0106 - val_mae: 0.0775 - val_mse: 0.0211
# Epoch 68/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0089 - mae: 0.0746 - mse: 0.0176 - val_loss: 0.0107 - val_mae: 0.0777 - val_mse: 0.0212
# Epoch 69/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0089 - mae: 0.0744 - mse: 0.0176 - val_loss: 0.0115 - val_mae: 0.0803 - val_mse: 0.0227
# Epoch 70/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0088 - mae: 0.0744 - mse: 0.0175 - val_loss: 0.0108 - val_mae: 0.0773 - val_mse: 0.0215
# Epoch 71/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 0.0088 - mae: 0.0740 - mse: 0.0174 - val_loss: 0.0107 - val_mae: 0.0775 - val_mse: 0.0213
# Epoch 72/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0088 - mae: 0.0739 - mse: 0.0174 - val_loss: 0.0108 - val_mae: 0.0777 - val_mse: 0.0215
# Epoch 73/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0087 - mae: 0.0736 - mse: 0.0173 - val_loss: 0.0114 - val_mae: 0.0788 - val_mse: 0.0226
# Epoch 74/200
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0087 - mae: 0.0737 - mse: 0.0173 - val_loss: 0.0111 - val_mae: 0.0782 - val_mse: 0.0220

# %% [markdown]
# Guardamos el modelo

# %%
loss = history.history['loss']
mae = history.history['mae']
mse = history.history['mse']
val_loss = history.history['val_loss']
val_mae = history.history['val_mae']
val_mse = history.history['val_mse']

epochs = range(1, len(loss) + 1)

# Crear la figura y los ejes de las subgráficas
fig, axs = plt.subplots(3, 1, figsize=(6, 11))

# Subgráfica 1: Loss
axs[0].plot(epochs, loss, label='Entrenamiento')
axs[0].plot(epochs, val_loss, label='Validación')
axs[0].set_yscale('log')
axs[0].set_title('Pérdida')
axs[0].set_xlabel('Épocas')
axs[0].legend()

# Subgráfica 2: MAE
axs[1].plot(epochs, mae, label='Entrenamiento')
axs[1].plot(epochs, val_mae, label='Validación')
axs[1].set_yscale('log')
axs[1].set_title('MAE')
axs[1].set_xlabel('Épocas')
axs[1].legend()

# Subgráfica 3: MSE
axs[2].plot(epochs, mse, label='Entrenamiento')
axs[2].plot(epochs, val_mse, label='Validación')
axs[2].set_yscale('log')
axs[2].set_title('MSE')
axs[2].set_xlabel('Épocas')
axs[2].legend()

# Configurar los ticks de los ejes horizontales para que sean enteros
for ax in axs:
    ax.set_xticks(epochs)
    ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Ajustar el espacio entre subgráficas
plt.tight_layout()
plt.show()

# %%
preds = []
# Obtener predicciones de las horas que utilizan datos conocidos
for step in range(num_steps): 
    if step > 0:
        for k in range(preds[0].shape[0]):
            for i in range(preds[0].shape[1]):
                for j in range(preds[0].shape[2]):
                    for s in range(step):
                        if len(X_test) > len(np.concatenate(preds, axis=0)):
                            X_test[24*step+k][i][7+num_steps*j+s] = preds[step-1-s][k][i][j]
    if len(preds) == 0:
        preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+24*step]]), verbose=0)) for i in range(24)])]
    elif len(preds) > 0:
        if len(X_test) > len(np.concatenate(preds, axis=0)):
            preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+24*step]]), verbose=0)) for i in range(24)])]
            
# Obtener predicciones que no utilizan datos conocidos
if len(X_test)>len(np.concatenate(preds, axis=0)):
    for l in range(5,len(X_test)//24):
        for k in range(preds[0].shape[0]):
            for i in range(preds[0].shape[1]):
                for j in range(preds[0].shape[2]):
                    X_test[l*24+k][i][7+num_steps*j] = preds[l-1][k][i][j]
                    X_test[l*24+k][i][8+num_steps*j] = preds[l-2][k][i][j]
                    X_test[l*24+k][i][9+num_steps*j] = preds[l-3][k][i][j]
                    X_test[l*24+k][i][10+num_steps*j] = preds[l-4][k][i][j]
                    X_test[l*24+k][i][11+num_steps*j] = preds[l-5][k][i][j]
        preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+l*24]]), verbose=0)) for i in range(24)])]
preds = np.concatenate(preds, axis=0)

# %%
# preds = []

# # 1 - Obtener predicciones de las horas 1 a 24
# preds += [np.array([np.squeeze(model.predict(np.array([X_test[i]]), verbose=0)) for i in range(24)])]

# # 2 - Obtener predicciones de las horas 25 a 48
# for k in range(preds[0].shape[0]):
#     for i in range(preds[0].shape[1]):
#         for j in range(preds[0].shape[2]):
#             X_test[24+k][i][7+5*j] = preds[0][k][i][j]

# preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+24]]), verbose=0)) for i in range(24)])]

# # 3 - Obtener predicciones de las horas 49 a 72
# for k in range(preds[0].shape[0]):
#     for i in range(preds[0].shape[1]):
#         for j in range(preds[0].shape[2]):
#             X_test[48+k][i][7+5*j] = preds[1][k][i][j]
#             X_test[48+k][i][8+5*j] = preds[0][k][i][j]
            
# preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+48]]), verbose=0)) for i in range(24)])]

# # 4 - Obtener predicciones de las horas 73 a 96
# for k in range(preds[0].shape[0]):
#     for i in range(preds[0].shape[1]):
#         for j in range(preds[0].shape[2]):
#             X_test[72+k][i][7+5*j] = preds[2][k][i][j]
#             X_test[72+k][i][8+5*j] = preds[1][k][i][j]
#             X_test[72+k][i][9+5*j] = preds[0][k][i][j]
            
# preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+72]]), verbose=0)) for i in range(24)])]

# # 5 - Obtener predicciones de las horas 97 a 120
# for k in range(preds[0].shape[0]):
#     for i in range(preds[0].shape[1]):
#         for j in range(preds[0].shape[2]):
#             X_test[96+k][i][7+5*j] = preds[3][k][i][j]
#             X_test[96+k][i][8+5*j] = preds[2][k][i][j]
#             X_test[96+k][i][9+5*j] = preds[1][k][i][j]
#             X_test[96+k][i][10+5*j] = preds[0][k][i][j]
            
# preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+96]]), verbose=0)) for i in range(24)])]

# # 6 - Obtener predicciones de las horas 121 a len(X_test)
# for l in range(5,len(X_test)//24):
#     for k in range(preds[0].shape[0]):
#         for i in range(preds[0].shape[1]):
#             for j in range(preds[0].shape[2]):
#                 X_test[l*24+k][i][7+5*j] = preds[l-1][k][i][j]
#                 X_test[l*24+k][i][8+5*j] = preds[l-2][k][i][j]
#                 X_test[l*24+k][i][9+5*j] = preds[l-3][k][i][j]
#                 X_test[l*24+k][i][10+5*j] = preds[l-4][k][i][j]
#                 X_test[l*24+k][i][11+5*j] = preds[l-5][k][i][j]
#     preds += [np.array([np.squeeze(model.predict(np.array([X_test[i+l*24]]), verbose=0)) for i in range(24)])]
# preds = np.concatenate(preds, axis=0)

# %%
loss, mae, mse = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}")
print(f"Test MAE:  {mae}")
print(f"Test MSE:  {mse}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0127 - mae: 0.0855 - mse: 0.0253
# Test loss: 0.011740193702280521
# Test MAE:  0.08288015425205231
# Test MSE:  0.023329786956310272

# %%
preds.shape
# Out:
# (168, 44, 11)

# %%
test_preds = pd.DataFrame(scaler_y.inverse_transform(preds.reshape(y_test.shape[0]*y_test.shape[1],y_test.shape[2])), columns = ['clouds', 'temp', 'pressure', 'humidity', 'temp_min', 
                                                                                        'temp_max', 'wind_speed', 'wind_deg', 'wind_gust', 'rain', 'snow'])
real_y = pd.DataFrame(scaler_y.inverse_transform(y_test.reshape(y_test.shape[0]*y_test.shape[1],y_test.shape[2])), columns = ['clouds', 'temp', 'pressure', 'humidity', 'temp_min', 
                                                                     'temp_max', 'wind_speed', 'wind_deg', 'wind_gust', 'rain', 'snow'])
real_x = X[split_2*44:].reset_index(drop = True)

# %%
predicciones = test_preds.merge(real_y, left_index=True, right_index=True, suffixes=('_pred', '_real')).merge(real_x, left_index=True, right_index=True)

predicciones = predicciones[['latitude', 'longitude', 'año', 'mes', 'día',
                             'día_semana', 'hora',
                             'clouds_pred','clouds_real',
                             'temp_pred', 'temp_real',
                             'pressure_pred', 'pressure_real',
                             'humidity_pred', 'humidity_real',
                             'temp_min_pred', 'temp_min_real',
                             'temp_max_pred', 'temp_max_real',
                             'wind_speed_pred', 'wind_speed_real',
                             'wind_deg_pred', 'wind_deg_real',
                             'wind_gust_pred', 'wind_gust_real',
                             'rain_pred', 'rain_real',
                             'snow_pred', 'snow_real']]

# %%
predicciones['longitude'] = predicciones['longitude'].round(4)
predicciones['latitude'] = predicciones['latitude'].round(4)
predicciones['año'] = predicciones['año'].round().astype('int')
predicciones['mes'] = predicciones['mes'].round().astype('int')
predicciones['día'] = predicciones['día'].round().astype('int')
predicciones['día_semana'] = predicciones['día_semana'].round().astype('int')
predicciones['hora'] = predicciones['hora'].round().astype('int')

# %% [markdown]
# Representamos las predicciones de temperatura frente a los valores reales

# %%
city = 'Las Palmas de Gran Canaria'
pred = predicciones.loc[(predicciones['latitude'] == coordinates[city][0]) & (predicciones['longitude'] == coordinates[city][1])].reset_index(drop = True)
pred = pred.join((pred['temp_pred']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_real']-273.15), rsuffix= '_celsius')
pred
plt.figure(figsize=(14, 6))
plt.plot(pred['temp_pred_celsius'], linestyle='-', label = 'Valor predicho')
plt.plot(pred['temp_real_celsius'], linestyle='-', label = 'Valor real')
plt.xlabel('Horas')
num_hours = len(pred)
plt.xticks(range(0, num_hours + 24, 24))
plt.ylim(0)
plt.legend()
plt.show()

# %%
city = 'Ourense'
pred = predicciones.loc[(predicciones['latitude'] == coordinates[city][0]) & (predicciones['longitude'] == coordinates[city][1])].reset_index(drop = True)
pred = pred.join((pred['temp_pred']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_real']-273.15), rsuffix= '_celsius')
pred
plt.figure(figsize=(14, 6))
plt.plot(pred['temp_pred_celsius'], linestyle='-', label = 'Valor predicho')
plt.plot(pred['temp_real_celsius'], linestyle='-', label = 'Valor real')
plt.xlabel('Horas')
num_hours = len(pred)
plt.xticks(range(0, num_hours + 24, 24))
plt.ylim(0)
plt.legend()
plt.show()

# %%
pred
# Out:
#      latitude  longitude   año  mes  día  día_semana  hora  clouds_pred  \
# 0     42.3409    -7.8641  2024    6   10           0     0    82.917267
# 1     42.3409    -7.8641  2024    6   10           0     1    77.147163
# 2     42.3409    -7.8641  2024    6   10           0     2    73.714760
# 3     42.3409    -7.8641  2024    6   10           0     3    70.909256
# 4     42.3409    -7.8641  2024    6   10           0     4    69.171455
# ..        ...        ...   ...  ...  ...         ...   ...          ...
# 163   42.3409    -7.8641  2024    6   16           6    19    78.303688
# 164   42.3409    -7.8641  2024    6   16           6    20    80.620941
# 165   42.3409    -7.8641  2024    6   16           6    21    83.438423
# 166   42.3409    -7.8641  2024    6   16           6    22    85.283051
# 167   42.3409    -7.8641  2024    6   16           6    23    84.407349
#
#      clouds_real   temp_pred  ...  wind_deg_pred  wind_deg_real  \
# 0           27.0  288.514862  ...     199.752518            8.0
# 1           24.0  287.463837  ...     194.599091            8.0
# 2           50.0  285.630219  ...     190.959854           12.0
# 3           81.0  284.479095  ...     213.240662           13.0
# 4           84.0  283.956879  ...     183.337143           16.0
# ..           ...         ...  ...            ...            ...
# 163         98.0  296.138397  ...     212.836227          258.0
# 164         96.0  294.343079  ...     195.547241          256.0
# 165        100.0  293.375793  ...     186.081512          251.0
# 166         91.0  291.814453  ...     179.482483          233.0
# 167         92.0  291.006592  ...     173.221405          210.0
#
#      wind_gust_pred  wind_gust_real  rain_pred  rain_real  snow_pred  \
# 0          6.128556            2.66   0.077343        0.0  -0.007943
# 1          4.501808            2.50   0.006187        0.0  -0.001549
# 2          4.108146            2.62  -0.399449        0.0  -0.003300
# 3          5.476789            2.94  -1.437771        0.0  -0.001880
# 4          2.769545            3.20  -0.344200        0.0  -0.004747
# ..              ...             ...        ...        ...        ...
# 163       11.395822            6.82  -3.506349        0.0  -0.024386
# 164       10.552890            6.25  -2.614951        0.0  -0.020984
# 165        8.870551            6.53  -0.990640        0.0  -0.015782
# 166        7.155448            2.75   0.140833        0.0  -0.015721
# 167        5.970984            2.75   0.244226        0.0  -0.018344
#
#      snow_real  temp_pred_celsius  temp_real_celsius
# 0          0.0          15.364868              14.33
# 1          0.0          14.313843              14.33
# 2          0.0          12.480225              14.33
# 3          0.0          11.329102              14.88
# 4          0.0          10.806885              14.33
# ..         ...                ...                ...
# 163        0.0          22.988403              20.05
# 164        0.0          21.193085              18.96
# 165        0.0          20.225800              17.92
# 166        0.0          18.664459              15.50
# 167        0.0          17.856598              14.84
#
# [168 rows x 31 columns]

# %%
variables = ['clouds','temp','pressure','humidity','temp_min','temp_max','wind_speed','wind_deg','wind_gust','rain','snow']

# %% [markdown]
# Calculamos el sesgo medio por ciudad de cada variable en la primera semana y vemos si es válido para utilizar como sesgo en la semana siguiente

# %%
for var in variables:
    predicciones[f'{var}_error'] = predicciones[f'{var}_real']-predicciones[f'{var}_pred']
    mean_error = predicciones[['latitude','longitude',f'{var}_error']].groupby(['latitude', 'longitude']).mean().rename(columns = {f'{var}_error':f'{var}_mean_error'})
    predicciones = predicciones.merge(mean_error, on=['latitude', 'longitude'])
    predicciones[f'{var}_pred_corr'] =  predicciones[f'{var}_pred'] + predicciones[f'{var}_mean_error']

# %%
city = 'Las Palmas de Gran Canaria'
pred = predicciones.loc[(predicciones['latitude'] == coordinates[city][0]) & (predicciones['longitude'] == coordinates[city][1])].reset_index(drop = True)
pred = pred.join((pred['temp_pred']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_pred_corr']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_real']-273.15), rsuffix= '_celsius')
pred
plt.figure(figsize=(14, 6))
plt.plot(pred['temp_pred_celsius'], linestyle='-', label = 'Valor predicho')
plt.plot(pred['temp_real_celsius'], linestyle='-', label = 'Valor real')
plt.plot(pred['temp_pred_corr_celsius'], linestyle='-', label = 'Valor predicho con corrección de sesgo')
plt.xlabel('Horas')
num_hours = len(pred)
plt.xticks(range(0, num_hours + 24, 24))
plt.ylim(0)
plt.legend()
plt.show()

# %%
stamp = []
for i in range(len(predicciones)):
    stamp += [pd.Timestamp(year=predicciones['año'][i], month=predicciones['mes'][i], day=predicciones['día'][i], hour=predicciones['hora'][i])]

coordinates_inv = {tuple(coords): city for city, coords in coordinates.items()}
def find_city(lat, lon):
    key = (lat, lon)
    return coordinates_inv.get(key, None)
predicciones['city'] = predicciones.apply(lambda row: find_city(row['latitude'], row['longitude']), axis=1)

predicciones = predicciones.join(pd.Series(stamp, name = 'datetime'))

# %%
cities = coordinates.keys()

huber_matrix = pd.DataFrame(index=cities, columns=variables)

for city in coordinates:
    for var in variables:
        huber_matrix.loc[city, var] = huber(predicciones[predicciones['city'] == city][f'{var}_real'].values, predicciones[predicciones['city'] == city][f'{var}_pred'].values.astype(np.float32))
huber_matrix = huber_matrix.astype(float)
plt.figure(figsize=(10, 8))
sns.heatmap(huber_matrix[['clouds','rain', 'snow','wind_speed', 'wind_deg', 'wind_gust']], vmin = 0, vmax = 10, annot=True, fmt='.2f', cmap=sns.color_palette("Blues", as_cmap=True).reversed(), xticklabels=['clouds','rain', 'snow','wind_speed', 'wind_deg', 'wind_gust'], yticklabels=cities, cbar=True)
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(huber_matrix[['temp','pressure','humidity','temp_min','temp_max']],vmin = 0, vmax = 10, annot=True, fmt='.2f', cmap=sns.color_palette("Blues", as_cmap=True).reversed(), xticklabels=['temp','pressure','humidity','temp_min','temp_max'], yticklabels=cities, cbar=True)
plt.show()

# %% [markdown]
# Para cada variable de cada ciudad, siendo $E_m$ el error medio:
# - $H_0: E_m = 0$
# - $H_1: E_m \ne 0$
#
# El código imprimirá ciudad, variable, estadistico t, ... en caso de que no haya evidencia significativa de sesgo en las predicciones.

# %%
alpha = 0.01
hipo_test = {}

for city in coordinates:
    hipo_test[city] = {}
    for var in variables:
        full_diff = predicciones[predicciones['city'] == city][f'{var}_error'].values
        t_stat, p_value = stats.ttest_1samp(full_diff, 0)
        hipo_test[city][var] = {'Estadistico t': t_stat, 'p-valor': p_value}
        if p_value < alpha:
            hipo_test[city][var]['test_result'] = "Hay evidencia significativa de sesgo en las predicciones."
        else:
            hipo_test[city][var]['test_result'] = "No hay evidencia significativa de sesgo en las predicciones."

count = 0
for city, results in hipo_test.items():
    
    for var, result in results.items():
        if result['test_result'] == "No hay evidencia significativa de sesgo en las predicciones.":
            count += 1
            print(f"Ciudad:             {city}")
            print(f"Variable:           {var}")
            print(f"Estadístico t:      {result['Estadistico t']}")
            print(f"Valor p:            {result['p-valor']}")
            print(f"Resultado del test: {result['test_result']}")
            print(f"Error medio:        {predicciones[predicciones['city'] == city][f'{var}_mean_error'].values[0]}\n")
# Out:
# Ciudad:             A Coruna
# Variable:           humidity
# Estadístico t:      1.5174900649692966
# Valor p:            0.13103373910664107
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.812042100088937
#
# Ciudad:             A Coruna
# Variable:           temp_min
# Estadístico t:      2.1995042461944214
# Valor p:            0.029215891285834357
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.4690790158226333
#
# Ciudad:             A Coruna
# Variable:           temp_max
# Estadístico t:      2.4766669669455355
# Valor p:            0.014257624033271535
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.4227612740652897
#
# Ciudad:             A Coruna
# Variable:           wind_gust
# Estadístico t:      0.6493314524332615
# Valor p:            0.5170162159269167
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.10269881523081234
#
# Ciudad:             A Coruna
# Variable:           rain
# Estadístico t:      -2.364362467017894
# Valor p:            0.019210083610427704
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.11322353153112566
#
# Ciudad:             Albacete
# Variable:           temp
# Estadístico t:      1.5848646290641009
# Valor p:            0.11488889293995025
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.5804565647670269
#
# Ciudad:             Albacete
# Variable:           temp_max
# Estadístico t:      -0.7310627239163694
# Valor p:            0.4657653266805909
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.2647943696521536
#
# Ciudad:             Albacete
# Variable:           wind_speed
# Estadístico t:      -0.01438631438200282
# Valor p:            0.9885389501796571
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0016491872923714832
#
# Ciudad:             Albacete
# Variable:           wind_deg
# Estadístico t:      0.8988735294519741
# Valor p:            0.37001423290015234
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        7.591670626685733
#
# Ciudad:             Almeria
# Variable:           wind_deg
# Estadístico t:      2.118449032386936
# Valor p:            0.03561646752866104
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        15.621451695760092
#
# Ciudad:             Almeria
# Variable:           snow
# Estadístico t:      -1.690979040136949
# Valor p:            0.09270623353037102
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0015426230873431667
#
# Ciudad:             Avila de los Caballeros
# Variable:           temp
# Estadístico t:      -0.16813823028035768
# Valor p:            0.8666779872141943
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.044581909179690286
#
# Ciudad:             Avila de los Caballeros
# Variable:           humidity
# Estadístico t:      -2.404928953004715
# Valor p:            0.017268920119567856
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -2.8402216093880788
#
# Ciudad:             Avila de los Caballeros
# Variable:           temp_max
# Estadístico t:      -1.1969862752527083
# Valor p:            0.23300831432214053
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.3228953624907022
#
# Ciudad:             Avila de los Caballeros
# Variable:           wind_deg
# Estadístico t:      0.6053226707838416
# Valor p:            0.5457863319995847
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        5.997277759370349
#
# Ciudad:             Badajoz
# Variable:           clouds
# Estadístico t:      0.27126612716745474
# Valor p:            0.7865213767153068
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.6394678751627604
#
# Ciudad:             Badajoz
# Variable:           humidity
# Estadístico t:      2.4474689912874874
# Valor p:            0.015421757392458251
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        2.0647578352973577
#
# Ciudad:             Badajoz
# Variable:           temp_max
# Estadístico t:      -1.025079574652642
# Valor p:            0.3068081759114378
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.20084849039713842
#
# Ciudad:             Badajoz
# Variable:           wind_speed
# Estadístico t:      -0.1043525416954941
# Valor p:            0.9170148037907917
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.013004582439150123
#
# Ciudad:             Badajoz
# Variable:           snow
# Estadístico t:      0.8699803623545435
# Valor p:            0.3855598799257478
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.001434530949197887
#
# Ciudad:             Barcelona
# Variable:           temp_max
# Estadístico t:      -1.98443396609454
# Valor p:            0.04884558831808662
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.4451117016020271
#
# Ciudad:             Barcelona
# Variable:           rain
# Estadístico t:      1.435919176232721
# Valor p:            0.1528958323490052
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.08776136629715828
#
# Ciudad:             Barcelona
# Variable:           snow
# Estadístico t:      -1.6853091513630913
# Valor p:            0.09379661688330822
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0018060890251512145
#
# Ciudad:             Burgos
# Variable:           temp_min
# Estadístico t:      -0.9757091826817966
# Valor p:            0.3306198351032501
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.24427025204613764
#
# Ciudad:             Burgos
# Variable:           wind_deg
# Estadístico t:      -0.6154733350166423
# Valor p:            0.5390800246550802
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -4.617670467921665
#
# Ciudad:             Caceres
# Variable:           temp_max
# Estadístico t:      0.3738076528153843
# Valor p:            0.7090215647754704
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.06700344993954606
#
# Ciudad:             Cadiz
# Variable:           clouds
# Estadístico t:      0.2964427564441862
# Valor p:            0.7672603196270353
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.5712368800526574
#
# Ciudad:             Cadiz
# Variable:           temp
# Estadístico t:      2.3592307719503385
# Valor p:            0.01946887067565916
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.39952524820963375
#
# Ciudad:             Cadiz
# Variable:           temp_min
# Estadístico t:      1.27264560449496
# Valor p:            0.20491279820597472
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.17404065086729656
#
# Ciudad:             Cadiz
# Variable:           wind_gust
# Estadístico t:      -1.8051867577654275
# Valor p:            0.0728467833611571
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.240895960959495
#
# Ciudad:             Castello de la Plana
# Variable:           clouds
# Estadístico t:      -0.3849390696416071
# Valor p:            0.7007723594744215
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -1.0273313352039881
#
# Ciudad:             Castello de la Plana
# Variable:           wind_deg
# Estadístico t:      -2.081299982904477
# Valor p:            0.03893219569601014
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -14.27900995526995
#
# Ciudad:             Ciudad Real
# Variable:           temp
# Estadístico t:      -2.3661278551685303
# Valor p:            0.019121760500124346
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.541125401088168
#
# Ciudad:             Ciudad Real
# Variable:           humidity
# Estadístico t:      0.4429937206310309
# Valor p:            0.6583435764511303
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.6578212465558734
#
# Ciudad:             Ciudad Real
# Variable:           wind_gust
# Estadístico t:      1.3991378446014167
# Valor p:            0.16362624312584798
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.45379832811298837
#
# Ciudad:             Ciudad Real
# Variable:           snow
# Estadístico t:      -0.29201867660057723
# Valor p:            0.7706347935694566
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0006131973125862022
#
# Ciudad:             Cordoba
# Variable:           humidity
# Estadístico t:      -0.6578984763991359
# Valor p:            0.5115092194497528
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.7269601027170816
#
# Ciudad:             Cordoba
# Variable:           wind_speed
# Estadístico t:      -1.0074382349825592
# Valor p:            0.31518169063893303
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.09780627750215079
#
# Ciudad:             Cordoba
# Variable:           snow
# Estadístico t:      0.9200623911524033
# Valor p:            0.3588672512951617
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.001283983777500994
#
# Ciudad:             Cuenca
# Variable:           humidity
# Estadístico t:      1.338042570155696
# Valor p:            0.18270164879749243
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        1.4451598099299838
#
# Ciudad:             Cuenca
# Variable:           wind_speed
# Estadístico t:      2.601087690125166
# Valor p:            0.010126880468949707
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.30478871126969653
#
# Ciudad:             Cuenca
# Variable:           wind_deg
# Estadístico t:      1.137995120829346
# Valor p:            0.25675251043402425
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        6.671374275570822
#
# Ciudad:             Girona
# Variable:           temp_max
# Estadístico t:      -1.4620957985745795
# Valor p:            0.14559421365379638
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.46385264078776245
#
# Ciudad:             Girona
# Variable:           wind_speed
# Estadístico t:      -1.0493616951332205
# Valor p:            0.29552790440954546
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.18628543445042203
#
# Ciudad:             Girona
# Variable:           wind_deg
# Estadístico t:      -2.081388891908446
# Valor p:            0.038923954548647395
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -17.228249459039596
#
# Ciudad:             Granada
# Variable:           temp_max
# Estadístico t:      1.797520814153278
# Valor p:            0.07405967340725819
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.39413632347471084
#
# Ciudad:             Granada
# Variable:           wind_speed
# Estadístico t:      0.35154058716043296
# Valor p:            0.7256259751415248
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.04033676204227266
#
# Ciudad:             Granada
# Variable:           snow
# Estadístico t:      2.564268877002876
# Valor p:            0.011220190189876487
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.0039039492862468165
#
# Ciudad:             Guadalajara
# Variable:           temp
# Estadístico t:      -1.1654115024103484
# Valor p:            0.24551432904019171
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.2584456743512839
#
# Ciudad:             Huelva
# Variable:           wind_speed
# Estadístico t:      0.15385572023641178
# Valor p:            0.877909263762821
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.01936345032283237
#
# Ciudad:             Huesca
# Variable:           humidity
# Estadístico t:      -1.3637154449967421
# Valor p:            0.1744925128877776
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.9285608473278228
#
# Ciudad:             Huesca
# Variable:           wind_speed
# Estadístico t:      -1.4243049296649428
# Valor p:            0.15622414276431373
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.1603948213372912
#
# Ciudad:             Huesca
# Variable:           snow
# Estadístico t:      1.6181702589628926
# Valor p:            0.10751306239180967
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.002431705410431494
#
# Ciudad:             Las Palmas de Gran Canaria
# Variable:           wind_deg
# Estadístico t:      -2.4189884290252945
# Valor p:            0.016637844678236865
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -24.711000624157133
#
# Ciudad:             Las Palmas de Gran Canaria
# Variable:           wind_gust
# Estadístico t:      -0.16098788223173421
# Valor p:            0.8722975289789188
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.03852504574117206
#
# Ciudad:             Leon
# Variable:           wind_deg
# Estadístico t:      1.9792757111738646
# Valor p:            0.04942865953626265
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        19.20240810939244
#
# Ciudad:             Lleida
# Variable:           wind_speed
# Estadístico t:      -0.9976583835984902
# Valor p:            0.31988840681286906
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.13350117728823707
#
# Ciudad:             Logrono
# Variable:           wind_speed
# Estadístico t:      -2.4690592067417225
# Valor p:            0.014553159542680803
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.3026759227684566
#
# Ciudad:             Logrono
# Variable:           wind_deg
# Estadístico t:      2.374407577025192
# Valor p:            0.018712284702670588
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        22.946403594244096
#
# Ciudad:             Logrono
# Variable:           wind_gust
# Estadístico t:      -1.4524085502912836
# Valor p:            0.1482642999398412
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.42553440743791204
#
# Ciudad:             Logrono
# Variable:           rain
# Estadístico t:      -1.110884613216382
# Valor p:            0.2682148733378674
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.16167763432133056
#
# Ciudad:             Lugo
# Variable:           wind_deg
# Estadístico t:      0.9209623427423185
# Valor p:            0.3583985705688366
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        7.651814506167459
#
# Ciudad:             Madrid
# Variable:           clouds
# Estadístico t:      1.6460829141247133
# Valor p:            0.10162736387618307
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        3.136896211476553
#
# Ciudad:             Madrid
# Variable:           temp
# Estadístico t:      -1.2815746269256816
# Valor p:            0.20176843122601867
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.2654493858700707
#
# Ciudad:             Madrid
# Variable:           temp_max
# Estadístico t:      0.18107027086530134
# Valor p:            0.856531986015324
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.03446044921874519
#
# Ciudad:             Madrid
# Variable:           wind_deg
# Estadístico t:      0.4567345828420071
# Valor p:            0.6484553357832844
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        4.341736748105005
#
# Ciudad:             Madrid
# Variable:           snow
# Estadístico t:      2.5483890243908327
# Valor p:            0.011723537116623377
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.003266810389634754
#
# Ciudad:             Malaga
# Variable:           temp
# Estadístico t:      0.741354890194955
# Valor p:            0.4595195238510723
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.21317335582915
#
# Ciudad:             Malaga
# Variable:           temp_min
# Estadístico t:      -2.434751370716977
# Valor p:            0.015954678924101386
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.6323933120001047
#
# Ciudad:             Malaga
# Variable:           temp_max
# Estadístico t:      0.4872926924124104
# Valor p:            0.6266899540889236
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.11993777320498213
#
# Ciudad:             Murcia
# Variable:           clouds
# Estadístico t:      2.0144196869400646
# Valor p:            0.04557028658478364
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        5.637484788894653
#
# Ciudad:             Murcia
# Variable:           temp
# Estadístico t:      2.0433595335031134
# Valor p:            0.04258820276145017
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.45538859049479086
#
# Ciudad:             Murcia
# Variable:           wind_deg
# Estadístico t:      0.5362657079717962
# Valor p:            0.5924885230764245
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        3.6324220839000896
#
# Ciudad:             Ourense
# Variable:           temp
# Estadístico t:      -0.8615849081226917
# Valor p:            0.3901513990771005
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.18542370024181715
#
# Ciudad:             Ourense
# Variable:           pressure
# Estadístico t:      1.3841633655817305
# Valor p:            0.1681553687316521
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.23520587739492493
#
# Ciudad:             Ourense
# Variable:           humidity
# Estadístico t:      -0.6365841449697499
# Valor p:            0.5252673416556848
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.673310325259254
#
# Ciudad:             Ourense
# Variable:           wind_speed
# Estadístico t:      -2.5318683381185174
# Valor p:            0.0122685559274193
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.19871761140369232
#
# Ciudad:             Ourense
# Variable:           wind_deg
# Estadístico t:      0.6213578254839571
# Valor p:            0.5352114470051462
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        5.49204158782959
#
# Ciudad:             Oviedo
# Variable:           clouds
# Estadístico t:      -0.3540380086133756
# Valor p:            0.7237569990441283
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.7695615859258742
#
# Ciudad:             Oviedo
# Variable:           temp
# Estadístico t:      -2.5046771246414123
# Valor p:            0.013215041410914527
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.4084344337100063
#
# Ciudad:             Oviedo
# Variable:           humidity
# Estadístico t:      1.209302148401675
# Valor p:            0.2282560129113172
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        1.2761239551362538
#
# Ciudad:             Oviedo
# Variable:           wind_deg
# Estadístico t:      -1.4415262274665361
# Valor p:            0.15130862076473833
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -13.053803852626256
#
# Ciudad:             Palencia
# Variable:           clouds
# Estadístico t:      -1.080237242376482
# Valor p:            0.28159413117114773
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -3.4450740019480386
#
# Ciudad:             Palencia
# Variable:           temp
# Estadístico t:      -1.8250754569956589
# Valor p:            0.0697763422752638
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.32506314232235567
#
# Ciudad:             Palencia
# Variable:           temp_min
# Estadístico t:      -1.847371591637971
# Valor p:            0.06646248295691845
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.3436989266531808
#
# Ciudad:             Palencia
# Variable:           temp_max
# Estadístico t:      2.216538832908029
# Valor p:            0.028005625498744326
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.37621196201869705
#
# Ciudad:             Palencia
# Variable:           wind_deg
# Estadístico t:      -1.7023573532050158
# Valor p:            0.09054903871631056
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -11.728591918945312
#
# Ciudad:             Pamplona
# Variable:           humidity
# Estadístico t:      1.5476813264414147
# Valor p:            0.12359199863518275
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        1.355520203000023
#
# Ciudad:             Pontevedra
# Variable:           pressure
# Estadístico t:      2.4854876825143215
# Valor p:            0.013921666617083417
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.48867579868862554
#
# Ciudad:             Pontevedra
# Variable:           humidity
# Estadístico t:      0.9825894836526147
# Valor p:            0.3272308998482688
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        1.291838010152181
#
# Ciudad:             Pontevedra
# Variable:           temp_min
# Estadístico t:      0.5184337578943496
# Valor p:            0.6048418911317582
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.13356945219493963
#
# Ciudad:             Pontevedra
# Variable:           wind_deg
# Estadístico t:      -1.1095462820752884
# Valor p:            0.26878976843947944
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -7.879759924752371
#
# Ciudad:             Santander
# Variable:           temp
# Estadístico t:      -0.8048051593704943
# Valor p:            0.4220764120796435
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.1733370172409763
#
# Ciudad:             Santander
# Variable:           pressure
# Estadístico t:      -0.10513093450222376
# Valor p:            0.9163980777953931
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.03079405285064259
#
# Ciudad:             Santander
# Variable:           temp_min
# Estadístico t:      -0.49614927607046466
# Valor p:            0.6204414658905875
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0964040629069091
#
# Ciudad:             Santander
# Variable:           rain
# Estadístico t:      1.2550938804182643
# Valor p:            0.21119816387015392
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.09780353842170124
#
# Ciudad:             Segovia
# Variable:           temp
# Estadístico t:      0.07878216630025314
# Valor p:            0.9373002087857483
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.01406701950799839
#
# Ciudad:             Segovia
# Variable:           temp_min
# Estadístico t:      -0.7694994186486284
# Valor p:            0.4426839132348165
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.15998743693033646
#
# Ciudad:             Segovia
# Variable:           temp_max
# Estadístico t:      1.7386256846136792
# Valor p:            0.08394358011249
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.31682278587704527
#
# Ciudad:             Segovia
# Variable:           wind_speed
# Estadístico t:      0.2863563308345469
# Valor p:            0.7749601481002082
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.02407045875276837
#
# Ciudad:             Sevilla
# Variable:           humidity
# Estadístico t:      1.0555898587549402
# Valor p:            0.2926803401936393
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        1.027956553867885
#
# Ciudad:             Sevilla
# Variable:           wind_speed
# Estadístico t:      1.8817981424781933
# Valor p:            0.06160331832319186
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.25056749025980635
#
# Ciudad:             Sevilla
# Variable:           snow
# Estadístico t:      1.2494854762002257
# Valor p:            0.21323592005330935
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.0014736222631253917
#
# Ciudad:             Soria
# Variable:           clouds
# Estadístico t:      -1.7264009545691987
# Valor p:            0.08612462633202266
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -5.193086521966117
#
# Ciudad:             Soria
# Variable:           wind_speed
# Estadístico t:      2.23238626683057
# Valor p:            0.026919096428915174
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.29493897032170074
#
# Ciudad:             Soria
# Variable:           wind_deg
# Estadístico t:      -0.24833910807517662
# Valor p:            0.8041771582967981
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -2.600055558340891
#
# Ciudad:             Tarragona
# Variable:           temp
# Estadístico t:      -0.3821998549266145
# Valor p:            0.7027990658072341
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.10949354625883617
#
# Ciudad:             Tarragona
# Variable:           temp_min
# Estadístico t:      -1.0599758254894847
# Valor p:            0.29068623275136884
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.3034584190731938
#
# Ciudad:             Tarragona
# Variable:           temp_max
# Estadístico t:      -0.6891266867969119
# Valor p:            0.49169988809196874
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.21705588931129344
#
# Ciudad:             Tarragona
# Variable:           wind_deg
# Estadístico t:      0.5557251082061319
# Valor p:            0.5791425259685885
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        4.389964648655483
#
# Ciudad:             Teruel
# Variable:           pressure
# Estadístico t:      -0.5199828807503297
# Valor p:            0.6037640996578497
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.11665344238280302
#
# Ciudad:             Valencia
# Variable:           temp
# Estadístico t:      -0.29069315810806406
# Valor p:            0.7716466916325719
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.06489145914713357
#
# Ciudad:             Valencia
# Variable:           temp_max
# Estadístico t:      0.9927388891353518
# Valor p:            0.32227344079668496
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.21126186552502008
#
# Ciudad:             Valencia
# Variable:           wind_speed
# Estadístico t:      -2.5225630995993917
# Valor p:            0.012585409276887498
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.24440171536945163
#
# Ciudad:             Valencia
# Variable:           wind_deg
# Estadístico t:      -0.32590848114447096
# Valor p:            0.7449016165163475
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -2.4593555359613326
#
# Ciudad:             Valencia
# Variable:           wind_gust
# Estadístico t:      -0.030700768019030895
# Valor p:            0.9755448384110197
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.007134706273209314
#
# Ciudad:             Valladolid
# Variable:           wind_gust
# Estadístico t:      0.0413561113745104
# Valor p:            0.9670614030641783
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.017155351778492367
#
# Ciudad:             Valladolid
# Variable:           rain
# Estadístico t:      1.8557489244442507
# Valor p:            0.06525165132105103
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.2733963776907573
#
# Ciudad:             Vitoria-Gasteiz
# Variable:           humidity
# Estadístico t:      -1.5704751910505297
# Valor p:            0.11819735624046002
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -1.1999759674072266
#
# Ciudad:             Vitoria-Gasteiz
# Variable:           wind_speed
# Estadístico t:      2.024888569706289
# Valor p:            0.04447164475125226
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.27850180645783745
#
# Ciudad:             Vitoria-Gasteiz
# Variable:           wind_deg
# Estadístico t:      0.4388531478579478
# Valor p:            0.6613351911250758
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        4.606657300676618
#
# Ciudad:             Zamora
# Variable:           temp_min
# Estadístico t:      0.06238432752630068
# Valor p:            0.9503313778095582
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.012374645414809038
#
# Ciudad:             Zamora
# Variable:           wind_deg
# Estadístico t:      -0.9219635596902658
# Valor p:            0.3578776091288055
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -6.657351493835449
#
# Ciudad:             Zamora
# Variable:           wind_gust
# Estadístico t:      0.8968864184697454
# Valor p:            0.3710706267988271
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        0.3804438796408829
#
# Ciudad:             Zaragoza
# Variable:           snow
# Estadístico t:      -0.5067540630231787
# Valor p:            0.6129958229106989
# Resultado del test: No hay evidencia significativa de sesgo en las predicciones.
# Error medio:        -0.0005317648229677053

# %%
count
# Out:
# 125

# %%
predicciones = predicciones.sort_values(["city","datetime"])
for var in variables:
    a = []
    for city in coordinates:
        if hipo_test[city][var]['test_result'] == "Hay evidencia significativa de sesgo en las predicciones.":
            a.extend(predicciones[predicciones['city'] == city][f"{var}_pred_corr"].values)
        else:
            a.extend(predicciones[predicciones['city'] == city][f"{var}_pred"].values)
    predicciones[f"{var}_final"] = np.array(a)

# %% [markdown]
# En caso de que no haya evidencia significativa de sesgo en las predicciones, este código no imprimirá nada.

# %%
alpha = 0.01
hipo_test2 = {}
h_0 = 0
h_1 = 0

for city in coordinates:
    hipo_test2[city] = {}
    for var in variables:
        full_diff = predicciones[predicciones['city'] == city][f'{var}_real'].values-predicciones[predicciones['city'] == city][f'{var}_final'].values
        t_stat, p_value = stats.ttest_1samp(full_diff, 0)
        hipo_test2[city][var] = {'Estadistico t': t_stat, 'p-valor': p_value}
        if p_value < alpha:
            hipo_test2[city][var]['test_result'] = "Hay evidencia significativa de sesgo en las predicciones."
        else:
            hipo_test2[city][var]['test_result'] = "No hay evidencia significativa de sesgo en las predicciones."

count = 0
for city, results in hipo_test2.items():
    
    for var, result in results.items():
        if result['test_result'] == "Hay evidencia significativa de sesgo en las predicciones.":
            count += 1
            print(f"Ciudad:             {city}")
            print(f"Variable:           {var}")
            print(f"Estadístico t:      {result['Estadistico t']}")
            print(f"Valor p:            {result['p-valor']}")
            print(f"Resultado del test: {result['test_result']}")
            print(f"Error medio:        {predicciones[predicciones['city'] == city][f'{var}_mean_error'].values[0]}\n")

# %%
count
# Out:
# 0

# %%
city = 'Ourense'
pred = predicciones.loc[(predicciones['latitude'] == coordinates[city][0]) & (predicciones['longitude'] == coordinates[city][1])].reset_index(drop = True)
pred = pred.join((pred['temp_pred']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_pred_corr']-273.15), rsuffix= '_celsius')
pred = pred.join((pred['temp_real']-273.15), rsuffix= '_celsius')
pred
plt.figure(figsize=(14, 6))
plt.plot(pred['temp_pred_celsius'], linestyle='-', label = 'Valor predicho')
plt.plot(pred['temp_real_celsius'], linestyle='-', label = 'Valor real')
plt.plot(pred['temp_pred_corr_celsius'], linestyle='-', label = 'Valor predicho con corrección de sesgo')
plt.xlabel('Horas')
num_hours = len(pred)
plt.xticks(range(0, num_hours + 24, 24))
plt.ylim(0)
plt.legend()
plt.show()

# %%
city = 'Segovia'
pred = predicciones.loc[(predicciones['latitude'] == coordinates[city][0]) & (predicciones['longitude'] == coordinates[city][1])].reset_index(drop = True)
pred
plt.figure(figsize=(14, 6))
plt.plot(pred['pressure_pred'], linestyle='-', label = 'Valor predicho')
plt.plot(pred['pressure_real'], linestyle='-', label = 'Valor real')
plt.plot(pred['pressure_final'], linestyle='-', label = 'Valor predicho con correccion por sesgo')

plt.title(f'Presión (mb) en {city}')
plt.xlabel('Horas')
num_hours = len(pred)
plt.xticks(range(0, num_hours + 24, 24))
plt.legend()
plt.show()

# %%
cities = coordinates.keys()

huber_matrix = pd.DataFrame(index=cities, columns=variables)

for city in coordinates:
    for var in variables:
        huber_matrix.loc[city, var] = huber(predicciones[predicciones['city'] == city][f'{var}_real'].values, predicciones[predicciones['city'] == city][f'{var}_final'].values.astype(np.float32))
huber_matrix = huber_matrix.astype(float)
plt.figure(figsize=(10, 8))
sns.heatmap(huber_matrix[['clouds','rain', 'snow','wind_speed', 'wind_deg', 'wind_gust']], vmin = 0, vmax = 10, annot=True, fmt='.2f', cmap=sns.color_palette("Blues", as_cmap=True).reversed(), xticklabels=['clouds','rain', 'snow','wind_speed', 'wind_deg', 'wind_gust'], yticklabels=cities, cbar=True)
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(huber_matrix[['temp','pressure','humidity','temp_min','temp_max']],vmin = 0, vmax = 10, annot=True, fmt='.2f', cmap=sns.color_palette("Blues", as_cmap=True).reversed(), xticklabels=['temp','pressure','humidity','temp_min','temp_max'], yticklabels=cities, cbar=True)
plt.show()

# %%
mean_columns = huber_matrix.mean(axis=0)
print("Media por columnas:")
print(round(mean_columns,6))
# Out:
# Media por columnas:
# clouds        26.385879
# temp           1.900867
# pressure       2.198963
# humidity       9.169588
# temp_min       1.897149
# temp_max       1.881625
# wind_speed     0.860714
# wind_deg      81.745599
# wind_gust      2.300778
# rain           0.680544
# snow           0.000084
# dtype: float64
